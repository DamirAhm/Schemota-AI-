# %%
def analyze_dataframe(df):
    n_cols = 2 + 2
    
    selected_df = df.iloc[:, :n_cols]
    
    print(f"Index: {type(df.index)}")
    print()
    
    print("Types of columns:")
    print(selected_df.dtypes)
    print()
    
    print("Summary of columns:")
    print(selected_df.describe())
    print()
    
    print("First 5 rows:")
    print(selected_df.head())

# %%
import pandas as pd

df = pd.read_csv('diabetes_data_upload.csv')

analyze_dataframe(df)
# Out:
# Index: <class 'pandas.core.indexes.range.RangeIndex'>
#
# Types of columns:
# Age            int64
# Gender        object
# Polyuria      object
# Polydipsia    object
# dtype: object
#
# Summary of columns:
#               Age
# count  520.000000
# mean    48.028846
# std     12.151466
# min     16.000000
# 25%     39.000000
# 50%     47.500000
# 75%     57.000000
# max     90.000000
#
# First 5 rows:
#    Age Gender Polyuria Polydipsia
# 0   40   Male       No        Yes
# 1   58   Male       No         No
# 2   41   Male      Yes         No
# 3   45   Male       No         No
# 4   60   Male      Yes        Yes

# %%
df_yes = df[df['Polyuria'] == 'Yes']
df_no = df[df['Polyuria'] == 'No']

print(f"Yes: {df_yes.shape[0]} rows")
print(f"No: {df_no.shape[0]} rows")

print("\nFirst 5 rows of df_yes:")
print(df_yes.iloc[:, :7].head())

print("\nFirst 5 rows of df_no:")
print(df_no.iloc[:, :7].head())
# Out:
# Yes: 258 rows
# No: 262 rows
#
# First 5 rows of df_yes:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia
# 2   41   Male      Yes         No                 No      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
# 5   55   Male      Yes        Yes                 No      Yes        Yes
# 6   57   Male      Yes        Yes                 No      Yes        Yes
# 7   66   Male      Yes        Yes                Yes      Yes         No
#
# First 5 rows of df_no:
#     Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia
# 0    40   Male       No        Yes                 No      Yes         No
# 1    58   Male       No         No                 No      Yes         No
# 3    45   Male       No         No                Yes      Yes        Yes
# 9    70   Male       No        Yes                Yes      Yes        Yes
# 17   67   Male       No        Yes                 No      Yes        Yes

# %%
sorted_df = df.sort_values(by=['Polyuria', 'Polydipsia', 'Age'])

print(sorted_df[['Polyuria', 'Polydipsia', 'Age']].head())
print(sorted_df[['Polyuria', 'Polydipsia', 'Age']].tail())
# Out:
#     Polyuria Polydipsia  Age
# 68        No         No   25
# 235       No         No   26
# 219       No         No   27
# 277       No         No   27
# 286       No         No   27
#     Polyuria Polydipsia  Age
# 199      Yes        Yes   69
# 304      Yes        Yes   69
# 346      Yes        Yes   69
# 101      Yes        Yes   85
# 185      Yes        Yes   85

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pylab as plt
df = pd.read_csv('diabetes_data_upload.csv')
df1 = df.iloc[:,0:3]
plt.hist(df1.iloc[:,0])
plt.show()
plt.hist(df1.iloc[:,1])
plt.show()
plt.hist(df1.iloc[:,2])
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

axes[0].hist(df_yes['Age'], bins=10, color='blue', alpha=0.7, label='Polyuria: Yes')
axes[1].hist(df_no['Age'], bins=10, color='green', alpha=0.7, label='Polyuria: No')

axes[0].set_title('Age Distribution - Polyuria: Yes')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')

axes[1].set_title('Age Distribution - Polyuria: No')
axes[1].set_xlabel('Age')

axes[0].legend()
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.boxplot([df_yes['Age'], df_no['Age']], labels=['Polyuria: Yes', 'Polyuria: No'], widths=0.5)
plt.title('Age Distribution Comparison by Polyuria', fontsize=14)
plt.ylabel('Age', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\Damir\AppData\Local\Temp\ipykernel_22176\1783941987.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df_yes['Age'], df_no['Age']], labels=['Polyuria: Yes', 'Polyuria: No'], widths=0.5)

# %%
# No need to import pandas again or read the CSV again as these are already done
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 1)

print(df.head())
pd.plotting.scatter_matrix(df[['Age', 'Polyuria', 'Polydipsia']], 
                          c=['red' if c == 1 else 'blue' for c in df['class']], alpha=0.1, ax=axes, diagonal='hist')


plt.tight_layout()
plt.show()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...
